# %%
! pip3 install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 11.1 MB 188 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 30.3 MB 1.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 309 kB 706 kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import numpy as np  
import pandas as pd

# %%
df = pd.read_csv('/Users/agrimagupta/vedam classes/sem - 3/Machine learning sem3/classes/pandas/Titanic-Dataset.csv')
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
from sklearn.model_selection import KNeighborsClassifier
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.model_selection import KNeighborsClassifier
#
# ImportError: cannot import name 'KNeighborsClassifier' from 'sklearn.model_selection' (/Users/agrimagupta/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/__init__.py)
